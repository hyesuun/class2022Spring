# %% [markdown]
# <a href="https://colab.research.google.com/github/hyesuun/class2022Spring/blob/main/20220425.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #auto correlation
# : correlation of a signal with a delayed copy of itself as a function of delay.시차값 사이의 선형 관계를 측정한다.

# %% [markdown]
# *   autocorrelation을 자기상관이라고 하며, 자기상관함수는 어떤 무작위의 신호가 두 시각에 취하는 값의 상관 관계를 나타내는 함수이다.
# *   확률 과정 {X(t)}의 시간 차 t인 두 시점을 각각 t1과 t1＋t라 할 때 표본값의 곱의 집합 평균 Y(t1, t1＋t)＝E(X(t1) X(t1＋t))가 {X(t)}의 자기 상관 함수이다.

# %% [markdown]
# #RMS(root measure squere)
# : 제곱평균제곱근. 변화하는 값의 크기에 대한 통계적 척도이다.

# %% [markdown]
# ![화면 캡처 2022-04-27 045927.png](data:image/png;base64,...)
